# %% [markdown]
# ##### Exercício 5.10
#
# **Num tribunal que julga infrações de trânsito, os infratores são classificados segundo três quesitos: se seus documentos estão em dia, se a infração é leve ou grave e se cometeram ou não alguma infração nos doze meses anteriores.**
#
# **(a) Construa um diagrama de árvore mostrando as várias maneiras pelas quais um infra-tor pode ser classificado pelo tribunal.**
#
# ![Untitled diagram-2024-03-10-030515.png](<attachment:Untitled diagram-2024-03-10-030515.png>)
#
# **(b) Se há 20 infratores em cada uma das oito categorias obtidas na parte (a) e o juiz passar um sermão em cada infrator cujos documentos não estão em dia, quantos dos infratores ouvirão um sermão?**
#
# Sob a condição de que há 4 categorias na condição "Documentos não estão em dia", o cálculo pode ser realizado por: 4 x 20 = 80 infratores.
#
# **(c) Se o juiz aplicar uma multa de $600 a cada infrator que cometeu uma infração grave e/ou uma infração nos últimos doze meses anteriores, quantos dos infratores receberão uma multa de $600?**
#
# Para realizar o cálculo, devemos considerar:
#
# - Todos os infratores com infração grave (4 categorias: com e sem documentos em dia, com e sem infração anterior).
# - Infratores com infração leve mas com infração anterior (2 categorias: com e sem documentos em dia).
#
# Totalizando 6 categorias, o cálculo seria: 6 x 20 = 120 infratores.
#
# **(d) Quantos infratores ouvirão um sermão e receberão uma multa de $600?**
#
# - Infratores com documentos não em dia e infração grave (2 categorias: com e sem infração anterior).
# - Infratores com documentos não em dia, infração leve, mas com infração anterior (1 categoria).
#
# Totalizando 3 categorias, o cálculo é: 3 x 20 = 60 infratores.
#
# ##### Exercício 5.28
#
# **Um psicólogo prepara um teste de memória utilizando palavras sem sentido de quatro letras, escolhendo a primeira letra da palavra dentre as consoantes q, w, x e z, a segunda letra dentre as vogais a, i e u, a terceira letra dentre as consoantes c, f e p e a quarta letra dentre as vogais e e o. Quantas dessas palavras sem sentido de quatro letras:**
#
# **(a) o psicólogo pode construir?**
#
# Para o cálculo, temos que são:
#
# - Primeira letra (4 opções)
# - Segunda letra (3 opções)
# - Terceira letra (3 opções)
# - Quarta letra (2 opções)
#
# Portanto, o cálculo seria: 4 x 3 x 3 x 2 = 72 palavras.
#
# **(b) começam com a letra q?**
#
# - Primeira letra (1 opção)
# - Segunda letra (3 opções)
# - Terceira letra (3 opções)
# - Quarta letra (2 opções)
#
# Então, o cálculo seria: 1 x 3 x 3 x 2 = 18 palavras que começam com a letra q.
#
# **(c) começam com a letra z e terminam com a letra o?**
#
# - Primeira letra (1 opção)
# - Segunda letra (3 opções)
# - Terceira letra (3 opções)
# - Quarta letra (1 opções)
#
# O cálculo é feito por: 1 x 3 x 3 x 1 = 9 palavras que começam com z e terminam com o.
#
# ##### Exercício 5.37
#
# **A contagem do número de resultados possíveis em jogos de azar é praticada há muitos séculos. Não havia somente o aspecto da aposta mas os resultados que ocorriam também eram considerados como indicação de intenções divinas. Foi há cerca de 1.000 anos que um bispo do que é hoje a Bélgica determinou que existem 56 maneiras distintas em que três dados podem cair, desde que estejamos interessados apenas no resultado global e não nos resultados de cada dado individualmente. Ele associou uma virtude a cada uma dessas possibilidades e cada pecador devia concentrarse por algum tempo na virtude que correspondia à sua jogada dos dados.**
#
# **(a) Encontre o número de maneiras nas quais três dados podem apresentar o mesmo número de pontos.**
#
# Como existem 3 dados, e cada um possui 6 possibilidades de resultado, então existem 6 maneiras nas quais os três apresentam o mesmo número:
#
# - 111
# - 222
# - 333
# - 444
# - 555
# - 666
#
# **(b) Encontre o número de maneiras nas quais dois dos três dados podem apresentar o mesmo número de pontos, enquanto que o terceiro dado apresenta um número diferente de pontos.**
#
# Existem 6 possibilidades de resultado para os dois primeiros dados, logo o terceiro dado só pode ter 5 possíveis resultados, que é o número restante de possibilidades diferentes do primeiro e segundo.
#
# O cálculo é: 6 x 5 = 30 maneiras.
#
# **(c) Encontre o número de maneiras nas quais todos os três dados podem apresentar três resultados diferentes.**
#
# O cálculo pode ser realizado através de: $ \frac{6.5.4}{3!} $ = $ \frac{120}{6} $ = 20 maneiras de três dados podem apresentar três resultados diferentes.
